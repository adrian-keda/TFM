# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy import stats

# %%
string = pd.read_csv('/home/amaqueda/TFM/ML_project/PPI_interactions/output_STRING/distances.all.gene_type.5.tsv', sep = '\t', header = 0)
huri = pd.read_csv('/home/amaqueda/TFM/ML_project/PPI_interactions/output_HuRI/distances.gene_type.tsv', sep = '\t', header = 0)

# %%
string
# Out:
#         genes  min_distance_cpg  avg_distance_cpg  min_distance_dna_repair  \
# 0        ARF5               3.0          4.320611                      3.0
# 1       COPG1               2.0          4.335878                      3.0
# 2       COPB1               2.0          4.305344                      3.0
# 3       COPG2               2.0          4.290076                      3.0
# 4     ARFGAP1               2.0          4.007634                      2.0
# ...       ...               ...               ...                      ...
# 9625     WBP2               2.0          3.610687                      2.0
# 9626     TEFM               3.0          5.114504                      3.0
# 9627   DYRK1B               2.0          4.114504                      2.0
# 9628   ELOA3C               2.0          3.870229                      2.0
# 9629   ELOA3B               2.0          3.870229                      2.0
#
# ...

# %%
huri
# Out:
#            Genes  min_CPG   avg_CPG  min_DNA_repair  avg_DNA_repair  \
# 0           TNMD      2.0  3.868217             2.0        4.056022
# 1          SPAG4      2.0  3.697674             2.0        3.801120
# 2        BCL2L13      2.0  3.472868             2.0        3.605042
# 3      GABARAPL2      1.0  3.054264             2.0        3.204482
# 4          VAMP3      2.0  3.581395             2.0        3.663866
# ...          ...      ...       ...             ...             ...
# 11553       BTLA      3.0  4.527132             3.0        4.585434
# 11554    C9orf43      2.0  4.604651             3.0        4.873950
# 11555    BHLHE41      NaN       NaN             NaN             NaN
# 11556     CAPZA2      3.0  4.480620             2.0        4.647059
# 11557    PIP4K2C      NaN       NaN             NaN             NaN
#
#        min_PIK_mTOR  avg_PIK_mTOR  min_Cell_Cycle  avg_Cell_Cycle  \
# 0               1.0      3.757895             3.0        3.852174
# ...

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_cpg'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_cpg'],
                             y = huri[~huri['avg_CPG'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_CPG']))
# Out:
# MannwhitneyuResult(statistic=5063.5, pvalue=2.3460953233239316e-08)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_cpg'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_cpg'],
                             y = huri[~huri['avg_CPG'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_CPG']))
# Out:
# MannwhitneyuResult(statistic=58783184.5, pvalue=2.9297600456837516e-104)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_dna_repair'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_dna_repair'],
                             y = huri[~huri['avg_DNA_repair'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_DNA_repair']))
# Out:
# MannwhitneyuResult(statistic=4640.0, pvalue=3.3256619856394e-10)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_dna_repair'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_dna_repair'],
                             y = huri[~huri['avg_DNA_repair'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_DNA_repair']))
# Out:
# MannwhitneyuResult(statistic=59622113.0, pvalue=1.6141343703205342e-124)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_pik_mtor'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_pik_mtor'],
                             y = huri[~huri['avg_PIK_mTOR'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_PIK_mTOR']))
# Out:
# MannwhitneyuResult(statistic=6422.0, pvalue=0.0008274129362747704)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_pik_mtor'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_pik_mtor'],
                             y = huri[~huri['avg_PIK_mTOR'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_PIK_mTOR']))
# Out:
# MannwhitneyuResult(statistic=56967922.5, pvalue=1.1751314414804665e-66)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_cell_cycle'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_cell_cycle'],
                             y = huri[~huri['avg_Cell_Cycle'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_Cell_Cycle']))
# Out:
# MannwhitneyuResult(statistic=4460.0, pvalue=4.7106220458809196e-11)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_cell_cycle'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_cell_cycle'],
                             y = huri[~huri['avg_Cell_Cycle'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_Cell_Cycle']))
# Out:
# MannwhitneyuResult(statistic=55695105.5, pvalue=2.2615565273912115e-45)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_chromatin'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_chromatin'],
                             y = huri[~huri['avg_Chromatin_Remodeling'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_Chromatin_Remodeling']))
# Out:
# MannwhitneyuResult(statistic=3868.5, pvalue=4.1276558690695196e-14)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_chromatin'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_chromatin'],
                             y = huri[~huri['avg_Chromatin_Remodeling'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_Chromatin_Remodeling']))
# Out:
# MannwhitneyuResult(statistic=52443041.0, pvalue=6.049818134934495e-10)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_all'].isnull() & (string['Gene_Type'] == 'CPG')]['avg_distance_all'],
                             y = huri[~huri['avg_ALL'].isnull() & (huri['Gene_Type'] == 'CPG')]['avg_ALL']))
# Out:
# MannwhitneyuResult(statistic=4950.0, pvalue=7.859054607825799e-09)

# %%
print(stats.mannwhitneyu(x = string[~string['avg_distance_all'].isnull() & (string['Gene_Type'] == 'Other_gene')]['avg_distance_all'],
                             y = huri[~huri['avg_ALL'].isnull() & (huri['Gene_Type'] == 'Other_Gene')]['avg_ALL']))
# Out:
# MannwhitneyuResult(statistic=58839599.0, pvalue=1.4531389104535344e-105)
